# %%
#question 1
B.RAINBOW

# %%
#question 2
s=(input().upper())
print(f'"{s}"')
# Out:
# lets upgrade
# "LETS UPGRADE"

# %%
#question 3
costPrice=float(input())
sellingPrice=float(input())
if(costPrice>sellingPrice):
    print("Loss")
elif(sellingPrice>costPrice):
    print("Profit")
else:
    print("Neither")
# Out:
# 20
# 30
# Profit

# %%
#question 3
costPrice=float(input())
sellingPrice=float(input())
if(costPrice>sellingPrice):
    print("Loss")
elif(sellingPrice>costPrice):
    print("Profit")
else:
    print("Neither")
# Out:
# 20
# 10
# Loss

# %%
#question 3
costPrice=float(input())
sellingPrice=float(input())
if(costPrice>sellingPrice):
    print("Loss")
elif(sellingPrice>costPrice):
    print("Profit")
else:
    print("Neither")
# Out:
# 20
# 20
# Neither

# %%
#question 3
costPrice=float(input())
sellingPrice=float(input())
if(costPrice>sellingPrice):
    print("Loss")
elif(sellingPrice>costPrice):
    print("Profit")
else:
    print("Neither")
# Out:
# 19
# 19
# Neither

# %%
#question 3
costPrice=float(input())
sellingPrice=float(input())
if(costPrice>sellingPrice):
    print("Loss")
elif(sellingPrice>costPrice):
    print("Profit")
else:
    print("Neither")
# Out:
# 23
# 7
# Loss

# %%
#question 3
costPrice=float(input())
sellingPrice=float(input())
if(costPrice>sellingPrice):
    print("Loss")
elif(sellingPrice>costPrice):
    print("Profit")
else:
    print("Neither")
# Out:
# 19
# 95
# Profit

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 20
# 1600

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 50
# 4000

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 72
# 5760

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 7
# 560

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 35
# 2800

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 23
# 1840

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 95
# 7600

# %%
#question 4
euros=int(input())
print(euros*80)
# Out:
# 18
# 1440
